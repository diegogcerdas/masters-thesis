# %%
import re
import spacy 
import enchant  
import numpy as np
import nltk
from nltk.corpus import wordnet as wn
from tqdm import tqdm
import pandas as pd

# Ensure you have the wordnet data
nltk.download('wordnet')

nlp = spacy.load("en_core_web_sm")
d = enchant.Dict("en_US")
# Out:
# [nltk_data] Downloading package wordnet to /home/diego/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def get_hyponyms(synset):
    hyponyms = set(synset.hyponyms())
    for hyponym in list(hyponyms):
        hyponyms |= get_hyponyms(hyponym)
    return hyponyms

def get_datapoint(category, synset):
    identifier = synset.name()
    name = identifier.split('.')[0].replace('_', ' ')
    description = f'{name}: {synset.definition()}'
    in_dict = all([d.check(w) for w in name.split()])
    datapoint = (category, identifier, name, description, in_dict)
    return datapoint

synsets = {

    'animals': [
        'placental.n.01', # mammals
        'amphibian.n.03', # amphibians
        'bird.n.01', # birds
        'fish.n.01', # fish
        'reptile.n.01' # reptiles
    ],

    # people
    'people': ['person.n.01'],

    # body parts
    'body parts': ['external_body_part.n.01'],

    # food
    'food': ['food.n.02'],

    # plants
    'plants': ['plant.n.02'],

    # nature
    'natural places': [
        'body_of_water.n.01',
        'geological_formation.n.01',
        'land.n.04'
    ],

    # man-made places
    'manmade places': [
        'building.n.01',
        'room.n.01',
        'way.n.06',
        'facility.n.01'
    ],

    # objects
    'objects': [
        'vehicle.n.01',
        'commodity.n.01',
        'instrumentality.n.03',
        'plaything.n.01',
        'article.n.02'
    ],

    # text
    'text': [
        'publication.n.01',
        'sign.n.02',
        'correspondence.n.01',
        'written_record.n.01'
    ],
}

# %%
datapoints = []

for cat, synset_names in tqdm(synsets.items()):

    for synset_name in synset_names:
    
        synset = wn.synset(synset_name)
        hyponyms = get_hyponyms(synset)
        hyponyms.add(synset)
        
        for hyponym in hyponyms:
            datapoint = get_datapoint(cat, hyponym)
            datapoints.append(datapoint)

df = pd.DataFrame(datapoints, columns=['category', 'identifier', 'name', 'description', 'in_dict'])
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 31.06it/s]

# %%
# show 20 random rows
df_in_dict = df[df.in_dict == True]

df_in_dict.to_csv('wordnet.csv', index=False)

# %%
df_in_dict = df_in_dict.sort_values(by='name').reset_index(drop=True)
df_in_dict.to_csv('wordnet.csv', index=False)

# %%
# get all rows where the word "restaurant" is in the description

df_in_dict[df_in_dict.description.str.contains('text')]
# Out:
#       category         identifier          name  \
# 6051    people        mercer.n.01        mercer
# 6706    people        redact.n.01        redact
# 8090    people       decoder.n.01       decoder
# 8312    people        tagger.n.01        tagger
# 8484    people     annotator.n.01     annotator
# 8927    people        editor.n.01        editor
# 9193    people       shearer.n.02       shearer
# 10341     food       bologna.n.02       bologna
# 10366     food          milt.n.01          milt
# 10398     food    breadfruit.n.02    breadfruit
# 10647     food       crumpet.n.01       crumpet
# 10671     food       cheddar.n.02       cheddar
# 10749     food           roe.n.01           roe
# 10785     food         frank.n.02         frank
# 11076     food          pear.n.01          pear
# 11444   plants          pear.n.02          pear
# 12260   plants    breadfruit.n.01    breadfruit
# 14466   plants      licorice.n.01      licorice
# 18177  objects       lectern.n.01       lectern
# 18766  objects       decoder.n.02       decoder
# 20435  objects        willow.n.02        willow
# 21452  objects   highlighter.n.02   highlighter
# 21730  objects          loom.n.01          loom
# 22477  objects   rotogravure.n.02   rotogravure
# 23697     text       edition.n.01       edition
# 23704     text       speller.n.02       speller
# 23710     text       crammer.n.04       crammer
# 23718     text        reader.n.08        reader
# 23735     text  introduction.n.04  introduction
# 23766     text      textbook.n.01      textbook
# 23778     text      glossary.n.01      glossary
# 23822     text        primer.n.01        primer
#
#                                              description  in_dict
# 6051     mercer: a dealer in textiles (especially silks)     True
# 6706   redact: someone who puts text into appropriate...     True
# 8090   decoder: the kind of intellectual who converts...     True
# 8312   tagger: someone who assigns labels to the gram...     True
# 8484   annotator: a commentator who writes notes to a...     True
# 8927   editor: a person responsible for the editorial...     True
# 9193   shearer: a workman who uses shears to cut leat...     True
# 10341  bologna: large smooth-textured smoked sausage ...     True
# 10366  milt: fish sperm or sperm-filled reproductive ...     True
# 10398  breadfruit: a large round seedless or seeded f...     True
# 10647  crumpet: a thick soft cake with a porous textu...     True
# 10671  cheddar: hard smooth-textured cheese; original...     True
# 10749  roe: fish eggs or egg-filled ovary; having a g...     True
# 10785  frank: a smooth-textured sausage of minced bee...     True
# 11076  pear: sweet juicy gritty-textured fruit availa...     True
# 11444  pear: Old World tree having sweet gritty-textu...     True
# 12260  breadfruit: native to Pacific islands and havi...     True
# 14466  licorice: deep-rooted coarse-textured plant na...     True
# 18177  lectern: desk or stand with a slanted top used...     True
# 18766  decoder: a machine that converts a coded text ...     True
# 20435  willow: a textile machine having a system of r...     True
# 21452  highlighter: a fluorescent marker used to mark...     True
# 21730  loom: a textile machine for weaving yarn into ...     True
# 22477  rotogravure: printed material (text and pictur...     True
# 23697  edition: the form in which a text (especially ...     True
# 23704  speller: an introductory textbook to teach spe...     True
# 23710          crammer: a textbook designed for cramming     True
# 23718  reader: one of a series of texts for students ...     True
# 23735  introduction: a basic or elementary instructio...     True
# 23766  textbook: a book prepared for use in schools o...     True
# 23778  glossary: an alphabetical list of technical te...     True
# 23822                   primer: an introductory textbook     True

# %%
def get_hyponyms(synset):
    hyponyms = set(synset.hyponyms())
    for hyponym in list(hyponyms):
        hyponyms |= get_hyponyms(hyponym)
    return hyponyms

word = 'electronic_text.n.01'
if '.' in word:
    synset = wn.synset(word)
    print(f'Description: {synset.definition()}')
    print(f'Hypernyms: {synset.hypernyms()} \n')

    print('Hyponyms:')
    hyponyms = get_hyponyms(synset)
    for hyponym in hyponyms:
        print(hyponym.name(), ': ', hyponym.definition())
else:
    synsets = np.array(wn.synsets(word, pos='n'))
    for synset in synsets:
        print('def', synset, synset.definition())
        print('hypo', synset, synset.hyponyms())
        print('hyper', synset, synset.hypernyms())
# Out:
# Description: text that is in a form that computer can store or display on a computer screen
# Hypernyms: [Synset('text.n.01')]
#
# Hyponyms:
# machine-displayable_text.n.01 :  electronic text that is stored and used in the form of a digital image
# machine-readable_text.n.01 :  electronic text that is stored as strings of characters and that can be displayed in a variety of formats
# hypertext.n.01 :  machine-readable text that is not sequential but is organized so that related items of information are connected; --Ted Nelson
